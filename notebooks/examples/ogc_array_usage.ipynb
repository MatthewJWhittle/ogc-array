# %% [markdown]
# # OGC Array Library Usage Example
#
# This notebook demonstrates how to use the OGC Array library to fetch geospatial data from OGC services and create visualizations.
#
# ## Features Demonstrated:
# - Fetching data from WCS services
# - Creating Dask-backed xarray objects
# - Plotting geospatial data
# - Working with different coordinate systems

# %%
import tilearray as ta

# %%
xmin, ymin = 414480, 392134
width = 500

xmax = xmin + width
ymax = ymin + width

bbox = xmin, ymin, xmax, ymax

# %%
url = "https://environment.data.gov.uk/spatialdata/lidar-composite-digital-terrain-model-dtm-1m/wcs"
layer_id = "lidar-composite-digital-terrain-model-dtm-1m"

ea_lidar_service = ta.create_wcs_service(url, layer_id)

# %%
array = ta.load_array(ea_lidar_service, bbox)

# %%
array
# Out:
# <xarray.DataArray 'concatenate-5a2320660fd22ffa6e3ddff5c1f3ca32' (y: 64000,
#                                                                   x: 250,
#                                                                   band: 256)> Size: 16GB
# dask.array<concatenate, shape=(64000, 250, 256), dtype=float32, chunksize=(256, 1, 256), chunktype=numpy.ndarray>
# Coordinates:
#   * y        (y) float64 512kB 3.921e+05 3.921e+05 ... 3.926e+05 3.926e+05
#   * x        (x) float64 2kB 4.145e+05 4.145e+05 4.145e+05 ... 4.15e+05 4.15e+05
#   * band     (band) int64 2kB 0 1 2 3 4 5 6 7 ... 249 250 251 252 253 254 255
# Attributes:
#     crs:           EPSG:4326
#     service_url:   https://environment.data.gov.uk/spatialdata/lidar-composit...
#     coverage_id:   lidar-composite-digital-terrain-model-dtm-1m
#     service_type:  WCS

# %%
print(array.dims)
print(array.shape)
print(array.attrs)
print(array.attrs["crs"])
# Out:
# ('y', 'x', 'band')
# (64000, 250, 256)
# {'crs': 'EPSG:4326', 'service_url': 'https://environment.data.gov.uk/spatialdata/lidar-composite-digital-terrain-model-dtm-1m/wcs', 'coverage_id': 'lidar-composite-digital-terrain-model-dtm-1m', 'service_type': 'WCS'}
# EPSG:4326
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 5
#       3 print(array.attrs)
#       4 print(array.attrs['crs'])
# ----> 5 print(array.attrs['transform'])
#       6 print(array.attrs['resampling'])
#       7 print(array.attrs['resampling'])
#
# KeyError: 'transform'
